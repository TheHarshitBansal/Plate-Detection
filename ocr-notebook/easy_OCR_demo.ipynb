# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /opt/anaconda3/lib/python3.11/site-packages (1.7.1)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: torchvision>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (0.18.1)
# Requirement already satisfied: opencv-python-headless in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (1.11.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (10.2.0)
# Requirement already satisfied: scikit-image in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (0.22.0)
# Requirement already satisfied: python-bidi in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (2.0.4)
# Requirement already satisfied: pyclipper in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in /opt/anaconda3/lib/python3.11/site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (2023.10.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (2023.4.12)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch->easyocr) (1.3.0)

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from IPython.display import Image

# %%
Image("plates/scanned_img_0.jpg")

# %%
reader = easyocr.Reader(['en'])

# %%
output = reader.readtext('plates/scanned_img_0.jpg')

# %%
cord = output[-1][0]
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
image = cv2.imread('plates/scanned_img_0.jpg')

# %%
cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 0, 255), 2)
# Out:
# array([[[  2, 255,   0],
#         [  1, 255,   0],
#         [  3, 255,   3],
#         ...,
#         [  6, 255,   2],
#         [  1, 255,   1],
#         [  0, 255,   0]],
#
#        [[  0, 254,   0],
#         [  9, 250,  11],
#         [ 20, 233,  30],
#         ...,
#         [ 32, 233,  35],
#         [ 20, 239,  21],
#         [ 15, 245,  19]],
#
#        [[  4, 255,   6],
#         [ 19, 234,  29],
#         [ 11, 138,  36],
#         ...,
#         [  0,  90,   0],
#         [  0, 116,   0],
#         [ 47, 216,  59]],
#
#        ...,
#
#        [[  6, 255,   2],
#         [ 36, 226,  41],
#         [138, 210, 158],
#         ...,
#         [108, 159, 132],
#         [ 79, 182,  97],
#         [ 67, 198,  83]],
#
#        [[  3, 250,   0],
#         [ 33, 236,  35],
#         [114, 231, 128],
#         ...,
#         [ 81, 181,  99],
#         [ 61, 200,  73],
#         [ 52, 212,  62]],
#
#        [[  7, 255,   3],
#         [  9, 245,   8],
#         [ 29, 237,  35],
#         ...,
#         [ 35, 231,  35],
#         [ 26, 235,  23],
#         [ 22, 241,  20]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plate_text = output[-1][1]
print("Detected License Plate Text:", plate_text)
# Out:
# Detected License Plate Text: NHI2 DE1433
